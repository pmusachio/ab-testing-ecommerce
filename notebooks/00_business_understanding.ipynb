# %% [markdown]
# # AB Testing Ecommerce - Business Understanding
#
# Este notebook documenta o problema de negocio, premissas, metrica de sucesso e plano analitico.

# %% [markdown]
# ## Business Problem
#
# Um ecommerce precisa decidir se uma nova experiencia de pagina aumenta conversao de forma estatisticamente confiavel.
#
# ## Objetivo
#
# Medir se uma nova experiencia de compra altera conversao de forma estatisticamente consistente.
#
# ## Metrica principal
#
# Lift absoluto, lift relativo, z-test de proporcoes e p-value

# %% [markdown]
# ## Business Assumptions
#
# - A decisao deve considerar significancia estatistica e tamanho de efeito.
# - Usuarios precisam estar corretamente separados entre controle e tratamento.
# - Mesmo lift pequeno pode ser relevante se a base ou receita forem grandes.

# %% [markdown]
# ## Solution Strategy
#
# 1. **Step 01. Data Description:** Validar schema, dimensoes, nulos, tipos e granularidade.
# 2. **Step 02. Feature Engineering:** Criar variaveis orientadas ao dominio do desafio.
# 3. **Step 03. Data Filtering:** Remover registros sem utilidade analitica ou com risco de vazamento.
# 4. **Step 04. Exploratory Data Analysis:** Validar hipoteses e separar sinais relevantes de ruido.
# 5. **Step 05. Data Preparation:** Imputar, escalar e codificar variaveis para modelagem.
# 6. **Step 06. Feature Selection:** Separar IDs, alvo, variaveis de entrada e colunas descartadas.
# 7. **Step 07. Machine Learning Modelling:** Treinar baseline reprodutivel e avaliar metricas tecnicas.
# 8. **Step 08. Hyperparameter/Fit Strategy:** Reservar espaco para tuning, threshold e comparacao de modelos.
# 9. **Step 09. Business Translation:** Converter metricas em decisao, priorizacao, risco, receita ou operacao.
# 10. **Step 10. Delivery:** Gerar relatorio estatistico, leitura de negocio e recomendacao executiva do experimento.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ab_testing_ecommerce.config import load_config
from ab_testing_ecommerce.data import load_training_frame, profile_dataframe
from ab_testing_ecommerce.features import prepare_features

config = load_config()
config["project"]
