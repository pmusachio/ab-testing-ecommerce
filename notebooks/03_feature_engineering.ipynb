# %% [markdown]
# # AB Testing Ecommerce - Feature Engineering
#
# Comparacao entre dados brutos e atributos preparados para modelagem.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from ab_testing_ecommerce.config import load_config
from ab_testing_ecommerce.data import load_training_frame, profile_dataframe
from ab_testing_ecommerce.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
features = prepare_features(df.copy(), config)
print('raw shape:', df.shape)
print('feature shape:', features.shape)
features.head()

# %%
new_columns = sorted(set(features.columns) - set(df.columns))
new_columns[:50], len(new_columns)

# %% [markdown]
# ## Feature rationale
#
# - Validacao de grupos controle e tratamento.
# - Calculo de conversao, lift absoluto e lift relativo.
# - Teste z de proporcoes para avaliar significancia estatistica.
